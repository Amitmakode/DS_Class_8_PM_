# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("F:\\Dataset\\student_cluster.csv")

# %%
new_df = df.head(20)

# %%
df.tail()
# Out:
#        Unnamed: 0     student_id first_name  last_name   age grade_level  \
# 52495       52495  DUP_STU105227        NaN      Davis  18.0         9th
# 52496       52496      STU102238      David     Garcia  15.0        11th
# 52497       52497      STU144268       Lisa   Martinez  16.0        10th
# 52498       52498            NaN     Ashley  Rodriguez  18.0         NaN
# 52499       52499            NaN     Daniel   Williams  16.0        10th
#
#        gender address_type  zip_code state  ...  class_size  \
# 52495    Male        Rural   94102.0    NY  ...        24.0
# 52496  Female          NaN   30301.0    FL  ...        21.0
# 52497  Female     Suburban   94102.0    TX  ...        32.0
# 52498    Male          NaN   10001.0    TX  ...        19.0
# 52499  Female        Urban   94102.0   NaN  ...        17.0
#
#       teacher_experience special_education  english_language_learner  \
# 52495               13.0               0.0                       0.0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'student_id', 'first_name', 'last_name', 'age',
#        'grade_level', 'gender', 'address_type', 'zip_code', 'state',
#        'household_size', 'parent_education', 'family_income',
#        'free_reduced_lunch', 'math_score', 'reading_score', 'science_score',
#        'writing_score', 'gpa', 'days_absent', 'tardiness_count',
#        'study_hours_weekly', 'extracurricular_activities', 'school_id',
#        'school_type', 'class_size', 'teacher_experience', 'special_education',
#        'english_language_learner', 'gifted_program', 'health_rating',
#        'counseling_visits', 'disciplinary_actions', 'internet_access',
#        'computer_access'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.class_size)
# Out:
# pandas.core.series.Series

# %%
df["last_name"]
# Out:
# 0            Brown
# 1          Johnson
# 2         Martinez
# 3              NaN
# 4            Jones
#            ...
# 52495        Davis
# 52496       Garcia
# 52497     Martinez
# 52498    Rodriguez
# 52499     Williams
# Name: last_name, Length: 52500, dtype: object

# %%
df[["last_name", "age", "first_name"]]
# Out:
#        last_name   age first_name
# 0          Brown  17.0       Emma
# 1        Johnson   NaN       John
# 2       Martinez  16.0      David
# 3            NaN  18.0      Sarah
# 4          Jones  18.0      Sarah
# ...          ...   ...        ...
# 52495      Davis  18.0        NaN
# 52496     Garcia  15.0      David
# 52497   Martinez  16.0       Lisa
# 52498  Rodriguez  18.0     Ashley
# 52499   Williams  16.0     Daniel
#
# [52500 rows x 3 columns]

# %%
[[[[1,2,3]]]]

# %%
data = [10, 20, 30, 40, 50]
series = pd.Series(data, index=['a', 'b', 'c', 'd', 'e'])
print(series)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
data_dict = {'A': 100, 'B': 200, 'C': 300}
series_dict = pd.Series(data_dict)
print(series_dict)
# Out:
# A    100
# B    200
# C    300
# dtype: int64

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'Age': [25, 30, 35, 28],
    'City': ['New York', 'London', 'Tokyo', 'Paris'],
    'Salary': [70000, 80000, 90000, 75000]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age      City  Salary
# 0    Alice   25  New York   70000
# 1      Bob   30    London   80000
# 2  Charlie   35     Tokyo   90000
# 3    Diana   28     Paris   75000

# %%
df["Name"]
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      Diana
# Name: Name, dtype: object

# %%
df[["Name", "Age"]]
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    Diana   28

# %%
new_df
# Out:
#     Unnamed: 0 student_id   first_name  last_name   age grade_level  gender  \
# 0            0  STU100000         Emma      Brown  17.0        11th  Female
# 1            1  STU100001         John    Johnson   NaN         NaN  Female
# 2            2  STU100002        David   Martinez  16.0         NaN  Female
# 3            3        NaN        Sarah        NaN  18.0        12th    Male
# 4            4        NaN        Sarah      Jones  18.0         NaN  Female
# 5            5  STU100005      Michael     Miller  15.0         9th  Female
# 6            6  STU100006         Emma        NaN  16.0        11th    Male
# 7            7        NaN       Daniel      Smith  16.0        10th  Female
# 8            8  STU100008         Emma   Martinez  16.0        10th  Female
# 9            9  STU100009       Ashley        NaN  18.0        10th    Male
# 10          10        NaN  Christopher     Miller  17.0        11th    Male
# ...

# %%
new_df.to_excel("newfile.xlsx")

# %%
new_df.to_json("newfile.json")

# %%
np.random.seed(42)
df = pd.DataFrame({
    'A': np.random.randn(100),
    'B': np.random.randint(1, 10, 100),
    'C': np.random.choice(['X', 'Y', 'Z'], 100),
    'D': pd.date_range('2023-01-01', periods=100, freq='D'),
    'E': np.random.randn(100) * 100
})

# %%
df.head()
# Out:
#           A  B  C          D           E
# 0  0.496714  9  Y 2023-01-01   23.229616
# 1 -0.138264  5  Y 2023-01-02   17.618092
# 2  0.647689  1  Y 2023-01-03 -115.256537
# 3  1.523030  3  Y 2023-01-04 -150.076839
# 4 -0.234153  8  Z 2023-01-05   16.502280

# %%
df.head()
# Out:
#           A  B  C          D           E
# 0  0.496714  9  Y 2023-01-01   23.229616
# 1 -0.138264  5  Y 2023-01-02   17.618092
# 2  0.647689  1  Y 2023-01-03 -115.256537
# 3  1.523030  3  Y 2023-01-04 -150.076839
# 4 -0.234153  8  Z 2023-01-05   16.502280

# %%
df.tail()
# Out:
#            A  B  C          D          E
# 95 -1.463515  3  Z 2023-04-06  94.914299
# 96  0.296120  9  X 2023-04-07 -23.922480
# 97  0.261055  3  X 2023-04-08  85.397471
# 98  0.005113  9  X 2023-04-09 -27.104046
# 99 -0.234587  2  Y 2023-04-10 -61.309468

# %%
df.shape
# Out:
# (100, 5)

# %%
df.size
# Out:
# 500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       100 non-null    float64
#  1   B       100 non-null    int32
#  2   C       100 non-null    object
#  3   D       100 non-null    datetime64[ns]
#  4   E       100 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int32(1), object(1)
# memory usage: 3.6+ KB

# %%
df.dtypes
# Out:
# A           float64
# B             int32
# C            object
# D    datetime64[ns]
# E           float64
# dtype: object

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
df.sample(5)
# Out:
#            A  B  C          D           E
# 31  1.852278  6  Y 2023-02-01  -31.784691
# 60 -0.479174  2  X 2023-03-02   64.716270
# 51 -0.385082  3  Y 2023-02-21  132.326381
# 14 -1.724918  3  X 2023-01-15  156.038014
# 80 -0.219672  3  X 2023-03-22  -62.970086
